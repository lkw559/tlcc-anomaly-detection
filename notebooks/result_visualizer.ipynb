# %% [markdown]
# # Result Visualizer

# %% [markdown]
# Different visualizations of anomaly detection result, including forecasts, reconstructions, anomaly scores, predicted and actual anomalies

# %%
pip install nbformat>=4.2.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import os
import pickle
from sklearn.metrics import f1_score, precision_score, recall_score
import plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode
import plotly.graph_objs as go
import cufflinks as cf
import glob
import sys
import json
import more_itertools as mit
from tqdm.notebook import tqdm
cf.go_offline()
init_notebook_mode

sys.path.insert(0, '.')
from plotting import Plotter
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# /tmp/ipykernel_88288/1226147920.py:1: DeprecationWarning:
#
# Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# ### Provide what output to visualize
# In case of multiple models trained for the same dataset, they will be saved in different folders named using the datetime of training.
# Use 'model_id' to specify which to load, '-1' for latest, '-2' for second latest, etc, or you can specify the exact datetime.

# %%
#res_path = './output/MSL'
#res_path = './output/SMAP'
#res_path = './output/SMD/1-1'
#res_path = './output/SMDDD'
res_path = './output/WADI'

# %%
print(res_path)
# Out:
# ./output/WADI

# %%
plotter = Plotter(res_path, model_id='-1')

plotter.result_summary()
# Out:
# Loading results of ./output/WADI/18062025_151104
# Result summary:
# Epsilon:
# 		precision: 0.46, recall: 0.97, F1: 0.62
# POT:
# 		precision: 0.00, recall: 0.00, F1: 0.00
# /home/timeseries/[filtered_data]S53CCF/Smartfactory/experiment_WaDi/./plotting.py:55: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /home/timeseries/[filtered_data]S53CCF/Smartfactory/experiment_WaDi/./plotting.py:31: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /home/timeseries/[filtered_data]S53CCF/Smartfactory/experiment_WaDi/./plotting.py:32: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`

# %% [markdown]
# ## Interactive plot
# - Interactive plot of forecastings, reconstructions,actual values, errors, etc of the specified feature.
# - Params:
#     - ```feature```: which feature to visualize
#     - ```plot_train```: whether to also plot for train set
#     - ```plot_errors```: whether to plot anomaly scores (error) for the feature
#     - ```plot_feature_anom```: if True, the feature-wise threshold and anomaly prediction is included
#     - ```start```: start index of dataset
#     - ```end```: end index of dataset
#
# If ```plot_feature_anom``` is set to True:
# - Predicted anomalies (for the particular feature) are visualized by a light blue rectangle.
# - As we only predict one feature for SMAP and MSL, the actual (true) anomalies are included using a red rectangle, making correctly predicted anomalies purple.

# %%
plotter.plot_feature(
    feature=0, 
    plot_train=True, 
    plot_errors=True, 
    plot_feature_anom=True,
    start=350, 
    end=3000
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plotter.plot_feature(
#       2     feature=0,
#       3     plot_train=True,
#       4     plot_errors=True,
#       5     plot_feature_anom=True,
#       6     start=350,
#       7     end=3000
#       8 )
#
# File /home/timeseries/[filtered_data]S53CCF/Smartfactory/experiment_WaDi/./plotting.py:269, in Plotter.plot_feature(self, feature, plot_train, plot_errors, plot_feature_anom, start, end)
#     247 lines = [
#     248     go.Scatter(
#     249         x=y_df["timestamp"],
#    (...)
#     265     #    line=dict(width=2)),
#     266 ]
#     268 fig = go.Figure(data=lines, layout=y_layout)
# --> 269 py.offline.iplot(fig)
#     271 e_lines = [
#     272     go.Scatter(
#     273         x=e_df["timestamp"],
#     274         y=e_df["e_s"],
#     275         name="Error",
#     276         line=dict(color="red", width=1))]
#     277 if plot_feature_anom:
#
# File /opt/conda/lib/python3.10/site-packages/plotly/offline/offline.py:387, in iplot(figure_or_data, show_link, link_text, validate, image, filename, image_width, image_height, config, auto_play, animation_opts)
#     382 post_script = build_save_image_post_script(
#     383     image, filename, image_height, image_width, "iplot"
#     384 )
#     386 # Show figure
# --> 387 pio.show(
#     388     figure,
#     389     validate=validate,
#     390     config=config,
#     391     auto_play=auto_play,
#     392     post_script=post_script,
#     393     animation_opts=animation_opts,
#     394 )
#
# File /opt/conda/lib/python3.10/site-packages/plotly/io/_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
#     424 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 425     raise ValueError(
#     426         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     427     )
#     429 display_jupyter_version_warnings()
#     431 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %% [markdown]
# ### Global (entity-level) Anomaly Predictions
# ```plot_global_predictions``` and ```plotly_global_predictions``` visualize the entity-level anomaly scores which are used to make anomaly predictions at entity-level.
# In ```plotly_global_predictions```:
# - Actual (true) anomalies are visualized by a red rectangle
# - Predicted anomalies are visualized by a blue rectangle.
# - Thus, if anomalies are predicted correctly the color of the rectangle will be purple.

# %%
plotter.plot_global_predictions(type="train")

# %%
plotter.plot_global_predictions(type="test")

# %%
plotter.plotly_global_predictions(type="test")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plotter.plotly_global_predictions(type="test")
#
# File /home/timeseries/[filtered_data]S53CCF/Smartfactory/experiment_WaDi/./plotting.py:493, in Plotter.plotly_global_predictions(self, type)
#     479 layout = {
#     480     "title": f"{type} set | Total error, predicted anomalies in blue, true anomalies in red if available "
#     481              f"(making correctly predicted in purple)",
#    (...)
#     485     "width": 1500
#     486 }
#     488 fig = go.Figure(
#     489     data=[go.Scatter(x=data_copy["timestamp"], y=tot_anomaly_scores, name='Error', line=dict(width=1, color="red")),
#     490           go.Scatter(x=data_copy["timestamp"], y=threshold, name='Threshold', line=dict(color="black", width=1, dash="dash"))],
#     491     layout=layout,
#     492 )
# --> 493 py.offline.iplot(fig)
#
# File /opt/conda/lib/python3.10/site-packages/plotly/offline/offline.py:387, in iplot(figure_or_data, show_link, link_text, validate, image, filename, image_width, image_height, config, auto_play, animation_opts)
#     382 post_script = build_save_image_post_script(
#     383     image, filename, image_height, image_width, "iplot"
#     384 )
#     386 # Show figure
# --> 387 pio.show(
#     388     figure,
#     389     validate=validate,
#     390     config=config,
#     391     auto_play=auto_play,
#     392     post_script=post_script,
#     393     animation_opts=animation_opts,
#     394 )
#
# File /opt/conda/lib/python3.10/site-packages/plotly/io/_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
#     424 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 425     raise ValueError(
#     426         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     427     )
#     429 display_jupyter_version_warnings()
#     431 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
# !python -c "import nbformat; print(nbformat.__version__)"
# Out:
# 5.10.4

# %%
# plotter.plot_all_features(type='test')
